# %% [markdown]
# # Mnist data set에서 train 60000장, test 10000장 이용한 CNN 분류모델

# %% [markdown]
# ### 코랩 구현 코드 (jupyter nb 생략가능)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/Test_one/mnist_cnn_practice'
# Out:
# /content/drive/MyDrive/Test_one/mnist_cnn_practice

# %%
pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.15.0

# %% [markdown]
# ## import library

# %%
import os
import numpy  as np
import pandas as pd

import matplotlib.pyplot as plt
import tensorflow               as tf
import tqdm
import tensorflow.keras.backend as K
from tensorflow                 import keras
from sklearn.model_selection    import train_test_split
import time
tf.random.set_seed(777)

# %% [markdown]
# # 학습/검증 데이터 (Raw data) 준비

# %%
# Download the mnist dataset using keras
data_train, data_test = tf.keras.datasets.mnist.load_data()

# Parse images and labels
(images_train, labels_train) = data_train
(images_test, labels_test) = data_test
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
images_train.shape
# Out:
# (60000, 28, 28)

# %%
labels_train[:10]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4], dtype=uint8)

# %%
images_train.shape, labels_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %% [markdown]
# ## 2D reshaping

# %%
images_train = images_train.reshape(images_train.shape[0],images_train.shape[1],images_train.shape[2],1)
images_test = images_test.reshape(images_test.shape[0],images_test.shape[1],images_test.shape[2],1)

# %%
labels_train_onehot = np.zeros((labels_train.shape[0],len(np.unique(labels_train))))

for i in range (labels_train.shape[0]):
    labels_train_onehot[i,labels_train[i]] = 1

# %%
labels_test_onehot  = np.zeros((labels_test.shape[0],len(np.unique(labels_test))))

for i in range (labels_test.shape[0]):
    labels_test_onehot[i,labels_test[i]] = 1

# %%
images_train.shape, labels_train_onehot.shape, images_test.shape, labels_test_onehot.shape
# Out:
# ((60000, 28, 28, 1), (60000, 10), (10000, 28, 28, 1), (10000, 10))

# %% [markdown]
# ## 2D-CNN(Convolution Neural Network)

# %% [markdown]
# #### Call back

# %%
# 학습개선이 되지않으면 epoch 중단
earlystopping = tf.keras.callbacks.EarlyStopping(  
    monitor='accuracy', min_delta=0.0001, patience=5, verbose=0,
    mode='auto', baseline=None, restore_best_weights=False
)

# %%
# CNN 학습 중 일정 epoch 마다 정확도(Accuracy) 표시 함수 생성
PrintAccPerEpochs = 1

class AccuracyPerEpoch(keras.callbacks.Callback):
    def on_epoch_end(self, epoch,logs=None):
        keras.callbacks.Callback()
        if epoch%PrintAccPerEpochs == 0:
            print("[{} Epochs] Accuracy : {:.2f}% ".format(epoch, logs["accuracy"]*100))

# %% [markdown]
# #### hyperparameter 설정

# %%
Epoch = 200

Kenel_S = [(3,3),(4,4),(5,5)]
Dense_N = [12, 18, 21 , 24]
Learn_R = [0.001]

print('Number of case : %d'%(len(Kenel_S)*len(Dense_N)*len(Learn_R)))
# Out:
# Number of case : 12

# %%
TrainData = images_train
TrainLabel = labels_train_onehot

TestData = images_test
TestLabel = labels_test_onehot

# %% [markdown]
# [CNN_models] 폴더에 모든 모델 저장

# %%
cnt = 0

Tr_result_temp = np.zeros((len(Kenel_S)*len(Dense_N)*len(Learn_R) , 5))
for i in range(len(Kenel_S)):
    kernelSize = Kenel_S[i]

    for j in range(len(Dense_N)):
        DenseNeuron = Dense_N[j]

        for k in range(len(Learn_R)):
            start_time = time.time()
            learningRate = Learn_R[k]
            epoch_cnt = 0

            ################ CNN 구조 재설계 ################

            def CNN_model(input_data):
                model = keras.Sequential()
                
                model.add(keras.layers.Conv2D(4, kernel_size=kernelSize, strides=1, padding='same', activation='relu',
                                              input_shape=(input_data.shape[1],input_data.shape[2],input_data.shape[3])))           # Convolution layer 1
                
                model.add(keras.layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))                    # Pooling layer 1
                
                model.add(keras.layers.Conv2D(8,  kernel_size=kernelSize, strides=1, padding='same', activation='relu')) # Convolution layer 2
                
                model.add(keras.layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='same'))                    # Pooling layer 2
                
                model.add(keras.layers.Conv2D(16, kernel_size=kernelSize, strides=1, padding='same', activation='relu')) # Convolution layer 3
                
                model.add(keras.layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='same')) 
                
                model.add(keras.layers.Flatten())
                model.add(keras.layers.Dense(units = DenseNeuron, activation='relu'))
                model.add(keras.layers.Dense(units = 10 , activation='softmax'))                                 # Output Layer

                model.compile(optimizer= keras.optimizers.Adam(learning_rate = learningRate),
                              loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
                return model

            model = CNN_model(TrainData)
            model.summary()

            print('\n\n[Grid search] case No.%d'%(cnt+1))
            print('Kernel size of each conv. layer : ', kernelSize)
            print('Num of neurons in Dense_H layer : %d'%(DenseNeuron))
            print('Learning rate : %.4f'%(learningRate))

            ################ CNN 학습 ################

            print("\n↓↓↓↓↓ Start CNN training ↓↓↓↓↓\n")

            tf.random.set_seed(777)
            History = model.fit(TrainData, TrainLabel, epochs=Epoch, verbose=0,
                                validation_data=(TestData, TestLabel), callbacks=[AccuracyPerEpoch(),earlystopping],batch_size = 256 )

            # 학습완료된 모델 기반 TestData 진단 정확도
            Loss, Accuracy = model.evaluate(TestData,  TestLabel, verbose=0)
            print("\n[Final Epochs] Accuracy : %.2f"%( Accuracy*100))      
            end_time = time.time()          
            print('time per epoch : %.2f'%((end_time-start_time)/Epoch),'sec') 
       

            print('\n\n#####################################################\n\n')

            ################ 학습결과 저장 ################

            # Hyperparameter 케이스별 모델성능 저장
            Tr_result_temp[cnt,0] = cnt
            Tr_result_temp[cnt,1] = (kernelSize)[0]
            Tr_result_temp[cnt,2] = DenseNeuron
            Tr_result_temp[cnt,3] = learningRate
            Tr_result_temp[cnt,4] = Accuracy

            cnt+=1

            # 학습완료된 CNN 모델 저장
            model.save("./[CNN_models]/CNN" +"_case%d.h5"%(cnt))

            # CNN 학습과정 저장
            # Hist = pd.DataFrame(np.zeros((Epoch,4)))
            # Hist.iloc[:,0] = np.array(History.history['loss']) # Early stopping 넣으니깐 학습과정 loss에서 길이가 안맞아서 일단 학습과정 저장은 전부 빼버렸습니다
            # Hist.iloc[:,1] = np.array(History.history['val_loss'])
            # Hist.iloc[:,2] = np.array(History.history['accuracy'])
            # Hist.iloc[:,3] = np.array(History.history['val_accuracy'])
#             Hist.to_csv("[CNN_history]/CNN_"+ SG_D +"_case%d_history.csv"%(cnt),header=None,index=None)

Tr_result_temp_pd = pd.DataFrame(Tr_result_temp, columns=['Case', 'Kernel_S', 
                                                          'Dense_N', 'Learn_R', 'Accuracy'])
Tr_result_temp_pd.to_csv("./[CNN_models]/Training_result.csv", index=None)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 4)         40
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 4)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 8)         296
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 16)          1168
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 12)                3084
#
#  dense_3 (Dense)             (None, 10)                130
#
# =================================================================
# Total params: 4,718
# Trainable params: 4,718
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.1
# Kernel size of each conv. layer :  (3, 3)
# Num of neurons in Dense_H layer : 12
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 19.75%
# [1 Epochs] Accuracy : 29.05%
# [2 Epochs] Accuracy : 30.60%
# [3 Epochs] Accuracy : 34.15%
# [4 Epochs] Accuracy : 63.81%
# [5 Epochs] Accuracy : 82.27%
# [6 Epochs] Accuracy : 88.51%
# [7 Epochs] Accuracy : 90.70%
# [8 Epochs] Accuracy : 92.06%
# [9 Epochs] Accuracy : 92.98%
# [10 Epochs] Accuracy : 93.57%
# [11 Epochs] Accuracy : 94.08%
# [12 Epochs] Accuracy : 94.38%
# [13 Epochs] Accuracy : 94.78%
# [14 Epochs] Accuracy : 94.92%
# [15 Epochs] Accuracy : 95.14%
# [16 Epochs] Accuracy : 95.43%
# [17 Epochs] Accuracy : 95.60%
# [18 Epochs] Accuracy : 95.69%
# [19 Epochs] Accuracy : 95.92%
# [20 Epochs] Accuracy : 95.86%
# [21 Epochs] Accuracy : 95.91%
# [22 Epochs] Accuracy : 96.05%
# [23 Epochs] Accuracy : 96.36%
# [24 Epochs] Accuracy : 96.27%
# [25 Epochs] Accuracy : 96.37%
# [26 Epochs] Accuracy : 96.65%
# [27 Epochs] Accuracy : 96.60%
# [28 Epochs] Accuracy : 96.67%
# [29 Epochs] Accuracy : 96.86%
# [30 Epochs] Accuracy : 96.88%
# [31 Epochs] Accuracy : 96.92%
# [32 Epochs] Accuracy : 97.00%
# [33 Epochs] Accuracy : 96.96%
# [34 Epochs] Accuracy : 97.18%
# [35 Epochs] Accuracy : 97.14%
# [36 Epochs] Accuracy : 97.10%
# [37 Epochs] Accuracy : 97.26%
# [38 Epochs] Accuracy : 97.25%
# [39 Epochs] Accuracy : 97.42%
# [40 Epochs] Accuracy : 97.40%
# [41 Epochs] Accuracy : 97.48%
# [42 Epochs] Accuracy : 97.48%
# [43 Epochs] Accuracy : 97.63%
# [44 Epochs] Accuracy : 97.62%
# [45 Epochs] Accuracy : 97.63%
# [46 Epochs] Accuracy : 97.70%
# [47 Epochs] Accuracy : 97.78%
# [48 Epochs] Accuracy : 97.88%
# [49 Epochs] Accuracy : 98.09%
# [50 Epochs] Accuracy : 98.03%
# [51 Epochs] Accuracy : 98.21%
# [52 Epochs] Accuracy : 98.27%
# [53 Epochs] Accuracy : 98.39%
# [54 Epochs] Accuracy : 98.44%
# [55 Epochs] Accuracy : 98.44%
# [56 Epochs] Accuracy : 98.36%
# [57 Epochs] Accuracy : 98.52%
# [58 Epochs] Accuracy : 98.52%
# [59 Epochs] Accuracy : 98.53%
# [60 Epochs] Accuracy : 98.55%
# [61 Epochs] Accuracy : 98.55%
# [62 Epochs] Accuracy : 98.63%
# [63 Epochs] Accuracy : 98.54%
# [64 Epochs] Accuracy : 98.61%
# [65 Epochs] Accuracy : 98.70%
# [66 Epochs] Accuracy : 98.73%
# [67 Epochs] Accuracy : 98.75%
# [68 Epochs] Accuracy : 98.68%
# [69 Epochs] Accuracy : 98.75%
# [70 Epochs] Accuracy : 98.79%
# [71 Epochs] Accuracy : 98.76%
# [72 Epochs] Accuracy : 98.78%
# [73 Epochs] Accuracy : 98.75%
# [74 Epochs] Accuracy : 98.83%
# [75 Epochs] Accuracy : 98.89%
# [76 Epochs] Accuracy : 98.84%
# [77 Epochs] Accuracy : 98.82%
# [78 Epochs] Accuracy : 98.84%
# [79 Epochs] Accuracy : 98.92%
# [80 Epochs] Accuracy : 98.87%
# [81 Epochs] Accuracy : 98.96%
# [82 Epochs] Accuracy : 98.87%
# [83 Epochs] Accuracy : 98.87%
# [84 Epochs] Accuracy : 98.95%
# [85 Epochs] Accuracy : 98.92%
# [86 Epochs] Accuracy : 98.96%
#
# [Final Epochs] Accuracy : 97.48
# time per epoch : 1.44 sec
#
#
# #####################################################
#
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 4)         40
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 4)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 8)         296
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 16)          1168
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 18)                4626
#
#  dense_5 (Dense)             (None, 10)                190
#
# =================================================================
# Total params: 6,320
# Trainable params: 6,320
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.2
# Kernel size of each conv. layer :  (3, 3)
# Num of neurons in Dense_H layer : 18
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 15.79%
# [1 Epochs] Accuracy : 57.63%
# [2 Epochs] Accuracy : 76.94%
# [3 Epochs] Accuracy : 87.17%
# [4 Epochs] Accuracy : 92.69%
# [5 Epochs] Accuracy : 94.30%
# [6 Epochs] Accuracy : 95.28%
# [7 Epochs] Accuracy : 95.80%
# [8 Epochs] Accuracy : 96.21%
# [9 Epochs] Accuracy : 96.52%
# [10 Epochs] Accuracy : 96.73%
# [11 Epochs] Accuracy : 96.88%
# [12 Epochs] Accuracy : 97.10%
# [13 Epochs] Accuracy : 97.36%
# [14 Epochs] Accuracy : 97.44%
# [15 Epochs] Accuracy : 97.59%
# [16 Epochs] Accuracy : 97.60%
# [17 Epochs] Accuracy : 97.75%
# [18 Epochs] Accuracy : 97.82%
# [19 Epochs] Accuracy : 97.86%
# [20 Epochs] Accuracy : 97.88%
# [21 Epochs] Accuracy : 97.99%
# [22 Epochs] Accuracy : 98.00%
# [23 Epochs] Accuracy : 98.15%
# [24 Epochs] Accuracy : 98.06%
# [25 Epochs] Accuracy : 98.10%
# [26 Epochs] Accuracy : 98.24%
# [27 Epochs] Accuracy : 98.28%
# [28 Epochs] Accuracy : 98.34%
# [29 Epochs] Accuracy : 98.34%
# [30 Epochs] Accuracy : 98.40%
# [31 Epochs] Accuracy : 98.43%
# [32 Epochs] Accuracy : 98.51%
# [33 Epochs] Accuracy : 98.45%
# [34 Epochs] Accuracy : 98.54%
# [35 Epochs] Accuracy : 98.50%
# [36 Epochs] Accuracy : 98.61%
# [37 Epochs] Accuracy : 98.62%
# [38 Epochs] Accuracy : 98.60%
# [39 Epochs] Accuracy : 98.73%
# [40 Epochs] Accuracy : 98.62%
# [41 Epochs] Accuracy : 98.72%
# [42 Epochs] Accuracy : 98.71%
# [43 Epochs] Accuracy : 98.90%
# [44 Epochs] Accuracy : 98.80%
# [45 Epochs] Accuracy : 98.78%
# [46 Epochs] Accuracy : 98.80%
# [47 Epochs] Accuracy : 98.92%
# [48 Epochs] Accuracy : 98.83%
# [49 Epochs] Accuracy : 98.95%
# [50 Epochs] Accuracy : 98.90%
# [51 Epochs] Accuracy : 98.94%
# [52 Epochs] Accuracy : 99.00%
# [53 Epochs] Accuracy : 99.01%
# [54 Epochs] Accuracy : 98.94%
# [55 Epochs] Accuracy : 99.05%
# [56 Epochs] Accuracy : 99.10%
# [57 Epochs] Accuracy : 99.10%
# [58 Epochs] Accuracy : 98.96%
# [59 Epochs] Accuracy : 99.05%
# [60 Epochs] Accuracy : 99.20%
# [61 Epochs] Accuracy : 99.08%
# [62 Epochs] Accuracy : 99.13%
# [63 Epochs] Accuracy : 99.20%
# [64 Epochs] Accuracy : 99.19%
# [65 Epochs] Accuracy : 99.20%
#
# [Final Epochs] Accuracy : 98.22
# time per epoch : 1.11 sec
#
#
# #####################################################
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 28, 28, 4)         40
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 4)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 8)         296
#
#  max_pooling2d_10 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 16)          1168
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 21)                5397
#
#  dense_7 (Dense)             (None, 10)                220
#
# =================================================================
# Total params: 7,121
# Trainable params: 7,121
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.3
# Kernel size of each conv. layer :  (3, 3)
# Num of neurons in Dense_H layer : 21
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 42.74%
# [1 Epochs] Accuracy : 79.46%
# [2 Epochs] Accuracy : 90.14%
# [3 Epochs] Accuracy : 93.53%
# [4 Epochs] Accuracy : 94.95%
# [5 Epochs] Accuracy : 95.67%
# [6 Epochs] Accuracy : 96.14%
# [7 Epochs] Accuracy : 96.57%
# [8 Epochs] Accuracy : 96.88%
# [9 Epochs] Accuracy : 97.18%
# [10 Epochs] Accuracy : 97.40%
# [11 Epochs] Accuracy : 97.58%
# [12 Epochs] Accuracy : 97.75%
# [13 Epochs] Accuracy : 97.89%
# [14 Epochs] Accuracy : 97.87%
# [15 Epochs] Accuracy : 98.11%
# [16 Epochs] Accuracy : 98.19%
# [17 Epochs] Accuracy : 98.26%
# [18 Epochs] Accuracy : 98.28%
# [19 Epochs] Accuracy : 98.37%
# [20 Epochs] Accuracy : 98.44%
# [21 Epochs] Accuracy : 98.47%
# [22 Epochs] Accuracy : 98.55%
# [23 Epochs] Accuracy : 98.55%
# [24 Epochs] Accuracy : 98.60%
# [25 Epochs] Accuracy : 98.64%
# [26 Epochs] Accuracy : 98.71%
# [27 Epochs] Accuracy : 98.75%
# [28 Epochs] Accuracy : 98.81%
# [29 Epochs] Accuracy : 98.78%
# [30 Epochs] Accuracy : 98.95%
# [31 Epochs] Accuracy : 98.86%
# [32 Epochs] Accuracy : 98.87%
# [33 Epochs] Accuracy : 98.93%
# [34 Epochs] Accuracy : 98.94%
# [35 Epochs] Accuracy : 98.91%
#
# [Final Epochs] Accuracy : 97.92
# time per epoch : 0.61 sec
#
#
# #####################################################
#
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 4)         40
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 8)         296
#
#  max_pooling2d_13 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 16)          1168
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 24)                6168
#
#  dense_9 (Dense)             (None, 10)                250
#
# =================================================================
# Total params: 7,922
# Trainable params: 7,922
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.4
# Kernel size of each conv. layer :  (3, 3)
# Num of neurons in Dense_H layer : 24
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 38.71%
# [1 Epochs] Accuracy : 71.89%
# [2 Epochs] Accuracy : 90.14%
# [3 Epochs] Accuracy : 93.85%
# [4 Epochs] Accuracy : 95.25%
# [5 Epochs] Accuracy : 96.05%
# [6 Epochs] Accuracy : 96.65%
# [7 Epochs] Accuracy : 96.90%
# [8 Epochs] Accuracy : 97.30%
# [9 Epochs] Accuracy : 97.42%
# [10 Epochs] Accuracy : 97.65%
# [11 Epochs] Accuracy : 97.83%
# [12 Epochs] Accuracy : 97.98%
# [13 Epochs] Accuracy : 98.02%
# [14 Epochs] Accuracy : 98.22%
# [15 Epochs] Accuracy : 98.25%
# [16 Epochs] Accuracy : 98.30%
# [17 Epochs] Accuracy : 98.51%
# [18 Epochs] Accuracy : 98.50%
# [19 Epochs] Accuracy : 98.47%
# [20 Epochs] Accuracy : 98.55%
# [21 Epochs] Accuracy : 98.54%
# [22 Epochs] Accuracy : 98.70%
# [23 Epochs] Accuracy : 98.69%
# [24 Epochs] Accuracy : 98.70%
# [25 Epochs] Accuracy : 98.77%
# [26 Epochs] Accuracy : 98.78%
# [27 Epochs] Accuracy : 98.83%
# [28 Epochs] Accuracy : 98.84%
# [29 Epochs] Accuracy : 98.95%
# [30 Epochs] Accuracy : 98.92%
# [31 Epochs] Accuracy : 98.87%
# [32 Epochs] Accuracy : 98.96%
# [33 Epochs] Accuracy : 99.03%
# [34 Epochs] Accuracy : 99.05%
# [35 Epochs] Accuracy : 99.00%
# [36 Epochs] Accuracy : 99.08%
# [37 Epochs] Accuracy : 99.10%
# [38 Epochs] Accuracy : 99.06%
# [39 Epochs] Accuracy : 99.22%
# [40 Epochs] Accuracy : 99.18%
# [41 Epochs] Accuracy : 99.22%
# [42 Epochs] Accuracy : 99.15%
# [43 Epochs] Accuracy : 99.26%
# [44 Epochs] Accuracy : 99.16%
# [45 Epochs] Accuracy : 99.19%
# [46 Epochs] Accuracy : 99.26%
# [47 Epochs] Accuracy : 99.30%
# [48 Epochs] Accuracy : 99.34%
# [49 Epochs] Accuracy : 99.43%
# [50 Epochs] Accuracy : 99.26%
# [51 Epochs] Accuracy : 99.37%
# [52 Epochs] Accuracy : 99.32%
# [53 Epochs] Accuracy : 99.23%
# [54 Epochs] Accuracy : 99.27%
#
# [Final Epochs] Accuracy : 98.25
# time per epoch : 0.98 sec
#
#
# #####################################################
#
#
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 28, 28, 4)         68
#
#  max_pooling2d_15 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 8)         520
#
#  max_pooling2d_16 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 7, 7, 16)          2064
#
#  max_pooling2d_17 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 12)                3084
#
#  dense_11 (Dense)            (None, 10)                130
#
# =================================================================
# Total params: 5,866
# Trainable params: 5,866
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.5
# Kernel size of each conv. layer :  (4, 4)
# Num of neurons in Dense_H layer : 12
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 16.37%
# [1 Epochs] Accuracy : 27.11%
# [2 Epochs] Accuracy : 38.34%
# [3 Epochs] Accuracy : 40.04%
# [4 Epochs] Accuracy : 41.68%
# [5 Epochs] Accuracy : 50.25%
# [6 Epochs] Accuracy : 63.59%
# [7 Epochs] Accuracy : 70.56%
# [8 Epochs] Accuracy : 72.79%
# [9 Epochs] Accuracy : 77.71%
# [10 Epochs] Accuracy : 82.28%
# [11 Epochs] Accuracy : 83.51%
# [12 Epochs] Accuracy : 87.05%
# [13 Epochs] Accuracy : 94.92%
# [14 Epochs] Accuracy : 96.01%
# [15 Epochs] Accuracy : 96.56%
# [16 Epochs] Accuracy : 97.05%
# [17 Epochs] Accuracy : 97.32%
# [18 Epochs] Accuracy : 97.48%
# [19 Epochs] Accuracy : 97.64%
# [20 Epochs] Accuracy : 97.75%
# [21 Epochs] Accuracy : 97.93%
# [22 Epochs] Accuracy : 97.97%
# [23 Epochs] Accuracy : 98.09%
# [24 Epochs] Accuracy : 98.14%
# [25 Epochs] Accuracy : 98.26%
# [26 Epochs] Accuracy : 98.26%
# [27 Epochs] Accuracy : 98.43%
# [28 Epochs] Accuracy : 98.32%
# [29 Epochs] Accuracy : 98.49%
# [30 Epochs] Accuracy : 98.51%
# [31 Epochs] Accuracy : 98.59%
# [32 Epochs] Accuracy : 98.63%
# [33 Epochs] Accuracy : 98.64%
# [34 Epochs] Accuracy : 98.67%
# [35 Epochs] Accuracy : 98.75%
# [36 Epochs] Accuracy : 98.87%
# [37 Epochs] Accuracy : 98.88%
# [38 Epochs] Accuracy : 98.83%
# [39 Epochs] Accuracy : 98.89%
# [40 Epochs] Accuracy : 98.85%
# [41 Epochs] Accuracy : 98.93%
# [42 Epochs] Accuracy : 99.01%
# [43 Epochs] Accuracy : 99.02%
# [44 Epochs] Accuracy : 99.08%
# [45 Epochs] Accuracy : 99.02%
# [46 Epochs] Accuracy : 98.95%
# [47 Epochs] Accuracy : 99.03%
# [48 Epochs] Accuracy : 99.19%
# [49 Epochs] Accuracy : 99.19%
# [50 Epochs] Accuracy : 99.22%
# [51 Epochs] Accuracy : 99.20%
# [52 Epochs] Accuracy : 99.15%
# [53 Epochs] Accuracy : 99.25%
# [54 Epochs] Accuracy : 99.27%
# [55 Epochs] Accuracy : 99.34%
# [56 Epochs] Accuracy : 99.26%
# [57 Epochs] Accuracy : 99.30%
# [58 Epochs] Accuracy : 99.38%
# [59 Epochs] Accuracy : 99.30%
# [60 Epochs] Accuracy : 99.36%
# [61 Epochs] Accuracy : 99.37%
# [62 Epochs] Accuracy : 99.42%
# [63 Epochs] Accuracy : 99.38%
# [64 Epochs] Accuracy : 99.36%
# [65 Epochs] Accuracy : 99.43%
# [66 Epochs] Accuracy : 99.49%
# [67 Epochs] Accuracy : 99.45%
# [68 Epochs] Accuracy : 99.41%
# [69 Epochs] Accuracy : 99.46%
# [70 Epochs] Accuracy : 99.59%
# [71 Epochs] Accuracy : 99.55%
# [72 Epochs] Accuracy : 99.52%
# [73 Epochs] Accuracy : 99.49%
# [74 Epochs] Accuracy : 99.42%
# [75 Epochs] Accuracy : 99.59%
#
# [Final Epochs] Accuracy : 97.94
# time per epoch : 1.64 sec
#
#
# #####################################################
#
#
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 28, 28, 4)         68
#
#  max_pooling2d_18 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 8)         520
#
#  max_pooling2d_19 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 7, 7, 16)          2064
#
#  max_pooling2d_20 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 18)                4626
#
#  dense_13 (Dense)            (None, 10)                190
#
# =================================================================
# Total params: 7,468
# Trainable params: 7,468
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.6
# Kernel size of each conv. layer :  (4, 4)
# Num of neurons in Dense_H layer : 18
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 25.79%
# [1 Epochs] Accuracy : 68.43%
# [2 Epochs] Accuracy : 89.83%
# [3 Epochs] Accuracy : 93.24%
# [4 Epochs] Accuracy : 94.83%
# [5 Epochs] Accuracy : 95.77%
# [6 Epochs] Accuracy : 96.41%
# [7 Epochs] Accuracy : 96.81%
# [8 Epochs] Accuracy : 97.17%
# [9 Epochs] Accuracy : 97.42%
# [10 Epochs] Accuracy : 97.74%
# [11 Epochs] Accuracy : 98.05%
# [12 Epochs] Accuracy : 97.98%
# [13 Epochs] Accuracy : 98.22%
# [14 Epochs] Accuracy : 98.32%
# [15 Epochs] Accuracy : 98.52%
# [16 Epochs] Accuracy : 98.55%
# [17 Epochs] Accuracy : 98.63%
# [18 Epochs] Accuracy : 98.77%
# [19 Epochs] Accuracy : 98.83%
# [20 Epochs] Accuracy : 98.81%
# [21 Epochs] Accuracy : 98.85%
# [22 Epochs] Accuracy : 98.94%
# [23 Epochs] Accuracy : 98.98%
# [24 Epochs] Accuracy : 99.08%
# [25 Epochs] Accuracy : 99.08%
# [26 Epochs] Accuracy : 99.10%
# [27 Epochs] Accuracy : 99.12%
# [28 Epochs] Accuracy : 99.08%
# [29 Epochs] Accuracy : 99.22%
# [30 Epochs] Accuracy : 99.19%
# [31 Epochs] Accuracy : 99.34%
# [32 Epochs] Accuracy : 99.30%
# [33 Epochs] Accuracy : 99.27%
# [34 Epochs] Accuracy : 99.35%
# [35 Epochs] Accuracy : 99.36%
# [36 Epochs] Accuracy : 99.42%
# [37 Epochs] Accuracy : 99.34%
# [38 Epochs] Accuracy : 99.27%
# [39 Epochs] Accuracy : 99.47%
# [40 Epochs] Accuracy : 99.51%
# [41 Epochs] Accuracy : 99.44%
# [42 Epochs] Accuracy : 99.46%
# [43 Epochs] Accuracy : 99.47%
# [44 Epochs] Accuracy : 99.51%
# [45 Epochs] Accuracy : 99.61%
# [46 Epochs] Accuracy : 99.57%
# [47 Epochs] Accuracy : 99.47%
# [48 Epochs] Accuracy : 99.48%
# [49 Epochs] Accuracy : 99.50%
# [50 Epochs] Accuracy : 99.55%
#
# [Final Epochs] Accuracy : 98.38
# time per epoch : 1.37 sec
#
#
# #####################################################
#
#
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 28, 28, 4)         68
#
#  max_pooling2d_21 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 8)         520
#
#  max_pooling2d_22 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 7, 7, 16)          2064
#
#  max_pooling2d_23 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 256)               0
#
#  dense_14 (Dense)            (None, 21)                5397
#
#  dense_15 (Dense)            (None, 10)                220
#
# =================================================================
# Total params: 8,269
# Trainable params: 8,269
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.7
# Kernel size of each conv. layer :  (4, 4)
# Num of neurons in Dense_H layer : 21
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 38.98%
# [1 Epochs] Accuracy : 81.52%
# [2 Epochs] Accuracy : 93.15%
# [3 Epochs] Accuracy : 95.36%
# [4 Epochs] Accuracy : 96.36%
# [5 Epochs] Accuracy : 97.00%
# [6 Epochs] Accuracy : 97.42%
# [7 Epochs] Accuracy : 97.66%
# [8 Epochs] Accuracy : 97.98%
# [9 Epochs] Accuracy : 98.10%
# [10 Epochs] Accuracy : 98.18%
# [11 Epochs] Accuracy : 98.40%
# [12 Epochs] Accuracy : 98.46%
# [13 Epochs] Accuracy : 98.51%
# [14 Epochs] Accuracy : 98.67%
# [15 Epochs] Accuracy : 98.68%
# [16 Epochs] Accuracy : 98.73%
# [17 Epochs] Accuracy : 98.87%
# [18 Epochs] Accuracy : 98.91%
# [19 Epochs] Accuracy : 98.99%
# [20 Epochs] Accuracy : 99.05%
# [21 Epochs] Accuracy : 99.07%
# [22 Epochs] Accuracy : 99.02%
# [23 Epochs] Accuracy : 99.16%
# [24 Epochs] Accuracy : 99.19%
# [25 Epochs] Accuracy : 99.26%
# [26 Epochs] Accuracy : 99.22%
# [27 Epochs] Accuracy : 99.22%
# [28 Epochs] Accuracy : 99.30%
# [29 Epochs] Accuracy : 99.26%
# [30 Epochs] Accuracy : 99.40%
# [31 Epochs] Accuracy : 99.33%
# [32 Epochs] Accuracy : 99.38%
# [33 Epochs] Accuracy : 99.40%
# [34 Epochs] Accuracy : 99.41%
# [35 Epochs] Accuracy : 99.34%
# [36 Epochs] Accuracy : 99.50%
# [37 Epochs] Accuracy : 99.45%
# [38 Epochs] Accuracy : 99.37%
# [39 Epochs] Accuracy : 99.45%
# [40 Epochs] Accuracy : 99.64%
# [41 Epochs] Accuracy : 99.52%
# [42 Epochs] Accuracy : 99.49%
# [43 Epochs] Accuracy : 99.44%
# [44 Epochs] Accuracy : 99.55%
# [45 Epochs] Accuracy : 99.65%
#
# [Final Epochs] Accuracy : 98.37
# time per epoch : 1.18 sec
#
#
# #####################################################
#
#
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 28, 28, 4)         68
#
#  max_pooling2d_24 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 8)         520
#
#  max_pooling2d_25 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 7, 7, 16)          2064
#
#  max_pooling2d_26 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 256)               0
#
#  dense_16 (Dense)            (None, 24)                6168
#
#  dense_17 (Dense)            (None, 10)                250
#
# =================================================================
# Total params: 9,070
# Trainable params: 9,070
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.8
# Kernel size of each conv. layer :  (4, 4)
# Num of neurons in Dense_H layer : 24
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 31.32%
# [1 Epochs] Accuracy : 71.57%
# [2 Epochs] Accuracy : 88.87%
# [3 Epochs] Accuracy : 93.12%
# [4 Epochs] Accuracy : 94.53%
# [5 Epochs] Accuracy : 95.53%
# [6 Epochs] Accuracy : 96.11%
# [7 Epochs] Accuracy : 96.51%
# [8 Epochs] Accuracy : 96.85%
# [9 Epochs] Accuracy : 97.14%
# [10 Epochs] Accuracy : 97.50%
# [11 Epochs] Accuracy : 97.58%
# [12 Epochs] Accuracy : 97.77%
# [13 Epochs] Accuracy : 97.95%
# [14 Epochs] Accuracy : 98.16%
# [15 Epochs] Accuracy : 98.18%
# [16 Epochs] Accuracy : 98.37%
# [17 Epochs] Accuracy : 98.44%
# [18 Epochs] Accuracy : 98.46%
# [19 Epochs] Accuracy : 98.60%
# [20 Epochs] Accuracy : 98.57%
# [21 Epochs] Accuracy : 98.58%
# [22 Epochs] Accuracy : 98.70%
# [23 Epochs] Accuracy : 98.87%
# [24 Epochs] Accuracy : 98.74%
# [25 Epochs] Accuracy : 98.82%
# [26 Epochs] Accuracy : 98.94%
# [27 Epochs] Accuracy : 98.96%
# [28 Epochs] Accuracy : 99.00%
# [29 Epochs] Accuracy : 99.06%
# [30 Epochs] Accuracy : 99.12%
# [31 Epochs] Accuracy : 99.02%
# [32 Epochs] Accuracy : 99.09%
# [33 Epochs] Accuracy : 99.14%
# [34 Epochs] Accuracy : 99.22%
# [35 Epochs] Accuracy : 99.15%
# [36 Epochs] Accuracy : 99.19%
# [37 Epochs] Accuracy : 99.19%
# [38 Epochs] Accuracy : 99.24%
# [39 Epochs] Accuracy : 99.29%
# [40 Epochs] Accuracy : 99.21%
# [41 Epochs] Accuracy : 99.27%
# [42 Epochs] Accuracy : 99.36%
# [43 Epochs] Accuracy : 99.41%
# [44 Epochs] Accuracy : 99.25%
# [45 Epochs] Accuracy : 99.40%
# [46 Epochs] Accuracy : 99.41%
# [47 Epochs] Accuracy : 99.27%
# [48 Epochs] Accuracy : 99.46%
# [49 Epochs] Accuracy : 99.38%
# [50 Epochs] Accuracy : 99.42%
# [51 Epochs] Accuracy : 99.47%
# [52 Epochs] Accuracy : 99.46%
# [53 Epochs] Accuracy : 99.48%
# [54 Epochs] Accuracy : 99.53%
# [55 Epochs] Accuracy : 99.47%
# [56 Epochs] Accuracy : 99.43%
# [57 Epochs] Accuracy : 99.59%
# [58 Epochs] Accuracy : 99.49%
# [59 Epochs] Accuracy : 99.53%
# [60 Epochs] Accuracy : 99.48%
# [61 Epochs] Accuracy : 99.53%
# [62 Epochs] Accuracy : 99.54%
#
# [Final Epochs] Accuracy : 98.25
# time per epoch : 1.43 sec
#
#
# #####################################################
#
#
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 28, 28, 4)         104
#
#  max_pooling2d_27 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 8)         808
#
#  max_pooling2d_28 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 7, 7, 16)          3216
#
#  max_pooling2d_29 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 256)               0
#
#  dense_18 (Dense)            (None, 12)                3084
#
#  dense_19 (Dense)            (None, 10)                130
#
# =================================================================
# Total params: 7,342
# Trainable params: 7,342
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.9
# Kernel size of each conv. layer :  (5, 5)
# Num of neurons in Dense_H layer : 12
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 10.76%
# [1 Epochs] Accuracy : 21.10%
# [2 Epochs] Accuracy : 22.53%
# [3 Epochs] Accuracy : 31.39%
# [4 Epochs] Accuracy : 34.34%
# [5 Epochs] Accuracy : 43.02%
# [6 Epochs] Accuracy : 46.04%
# [7 Epochs] Accuracy : 48.11%
# [8 Epochs] Accuracy : 52.58%
# [9 Epochs] Accuracy : 71.47%
# [10 Epochs] Accuracy : 82.04%
# [11 Epochs] Accuracy : 86.54%
# [12 Epochs] Accuracy : 95.92%
# [13 Epochs] Accuracy : 97.00%
# [14 Epochs] Accuracy : 97.36%
# [15 Epochs] Accuracy : 97.77%
# [16 Epochs] Accuracy : 98.01%
# [17 Epochs] Accuracy : 98.18%
# [18 Epochs] Accuracy : 98.36%
# [19 Epochs] Accuracy : 98.52%
# [20 Epochs] Accuracy : 98.66%
# [21 Epochs] Accuracy : 98.68%
# [22 Epochs] Accuracy : 98.78%
# [23 Epochs] Accuracy : 98.84%
# [24 Epochs] Accuracy : 98.92%
# [25 Epochs] Accuracy : 99.01%
# [26 Epochs] Accuracy : 98.99%
# [27 Epochs] Accuracy : 99.09%
# [28 Epochs] Accuracy : 99.06%
# [29 Epochs] Accuracy : 99.08%
# [30 Epochs] Accuracy : 99.12%
# [31 Epochs] Accuracy : 99.21%
# [32 Epochs] Accuracy : 99.17%
# [33 Epochs] Accuracy : 99.32%
# [34 Epochs] Accuracy : 99.24%
# [35 Epochs] Accuracy : 99.27%
# [36 Epochs] Accuracy : 99.30%
# [37 Epochs] Accuracy : 99.42%
# [38 Epochs] Accuracy : 99.38%
# [39 Epochs] Accuracy : 99.34%
# [40 Epochs] Accuracy : 99.26%
# [41 Epochs] Accuracy : 99.43%
# [42 Epochs] Accuracy : 99.46%
# [43 Epochs] Accuracy : 99.38%
# [44 Epochs] Accuracy : 99.36%
# [45 Epochs] Accuracy : 99.46%
# [46 Epochs] Accuracy : 99.58%
# [47 Epochs] Accuracy : 99.61%
# [48 Epochs] Accuracy : 99.43%
# [49 Epochs] Accuracy : 99.52%
# [50 Epochs] Accuracy : 99.52%
# [51 Epochs] Accuracy : 99.39%
# [52 Epochs] Accuracy : 99.57%
#
# [Final Epochs] Accuracy : 98.32
# time per epoch : 1.62 sec
#
#
# #####################################################
#
#
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 28, 28, 4)         104
#
#  max_pooling2d_30 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 8)         808
#
#  max_pooling2d_31 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 16)          3216
#
#  max_pooling2d_32 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 256)               0
#
#  dense_20 (Dense)            (None, 18)                4626
#
#  dense_21 (Dense)            (None, 10)                190
#
# =================================================================
# Total params: 8,944
# Trainable params: 8,944
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.10
# Kernel size of each conv. layer :  (5, 5)
# Num of neurons in Dense_H layer : 18
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 38.19%
# [1 Epochs] Accuracy : 81.82%
# [2 Epochs] Accuracy : 91.81%
# [3 Epochs] Accuracy : 95.63%
# [4 Epochs] Accuracy : 96.77%
# [5 Epochs] Accuracy : 97.29%
# [6 Epochs] Accuracy : 97.72%
# [7 Epochs] Accuracy : 98.02%
# [8 Epochs] Accuracy : 98.21%
# [9 Epochs] Accuracy : 98.31%
# [10 Epochs] Accuracy : 98.54%
# [11 Epochs] Accuracy : 98.69%
# [12 Epochs] Accuracy : 98.66%
# [13 Epochs] Accuracy : 98.87%
# [14 Epochs] Accuracy : 98.86%
# [15 Epochs] Accuracy : 98.99%
# [16 Epochs] Accuracy : 99.02%
# [17 Epochs] Accuracy : 99.11%
# [18 Epochs] Accuracy : 99.15%
# [19 Epochs] Accuracy : 99.08%
# [20 Epochs] Accuracy : 99.20%
# [21 Epochs] Accuracy : 99.20%
# [22 Epochs] Accuracy : 99.34%
# [23 Epochs] Accuracy : 99.33%
# [24 Epochs] Accuracy : 99.34%
# [25 Epochs] Accuracy : 99.37%
# [26 Epochs] Accuracy : 99.42%
# [27 Epochs] Accuracy : 99.30%
# [28 Epochs] Accuracy : 99.35%
# [29 Epochs] Accuracy : 99.41%
# [30 Epochs] Accuracy : 99.53%
# [31 Epochs] Accuracy : 99.50%
# [32 Epochs] Accuracy : 99.46%
# [33 Epochs] Accuracy : 99.41%
# [34 Epochs] Accuracy : 99.48%
# [35 Epochs] Accuracy : 99.54%
#
# [Final Epochs] Accuracy : 98.53
# time per epoch : 1.08 sec
#
#
# #####################################################
#
#
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_33 (Conv2D)          (None, 28, 28, 4)         104
#
#  max_pooling2d_33 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 8)         808
#
#  max_pooling2d_34 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 7, 7, 16)          3216
#
#  max_pooling2d_35 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 256)               0
#
#  dense_22 (Dense)            (None, 21)                5397
#
#  dense_23 (Dense)            (None, 10)                220
#
# =================================================================
# Total params: 9,745
# Trainable params: 9,745
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.11
# Kernel size of each conv. layer :  (5, 5)
# Num of neurons in Dense_H layer : 21
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 33.16%
# [1 Epochs] Accuracy : 53.36%
# [2 Epochs] Accuracy : 82.43%
# [3 Epochs] Accuracy : 94.58%
# [4 Epochs] Accuracy : 96.10%
# [5 Epochs] Accuracy : 96.68%
# [6 Epochs] Accuracy : 97.21%
# [7 Epochs] Accuracy : 97.50%
# [8 Epochs] Accuracy : 97.70%
# [9 Epochs] Accuracy : 98.02%
# [10 Epochs] Accuracy : 98.10%
# [11 Epochs] Accuracy : 98.22%
# [12 Epochs] Accuracy : 98.45%
# [13 Epochs] Accuracy : 98.58%
# [14 Epochs] Accuracy : 98.58%
# [15 Epochs] Accuracy : 98.69%
# [16 Epochs] Accuracy : 98.85%
# [17 Epochs] Accuracy : 98.92%
# [18 Epochs] Accuracy : 98.96%
# [19 Epochs] Accuracy : 99.05%
# [20 Epochs] Accuracy : 99.03%
# [21 Epochs] Accuracy : 99.06%
# [22 Epochs] Accuracy : 99.17%
# [23 Epochs] Accuracy : 99.31%
# [24 Epochs] Accuracy : 99.24%
# [25 Epochs] Accuracy : 99.21%
# [26 Epochs] Accuracy : 99.30%
# [27 Epochs] Accuracy : 99.33%
# [28 Epochs] Accuracy : 99.50%
# [29 Epochs] Accuracy : 99.30%
# [30 Epochs] Accuracy : 99.29%
# [31 Epochs] Accuracy : 99.38%
# [32 Epochs] Accuracy : 99.41%
# [33 Epochs] Accuracy : 99.49%
#
# [Final Epochs] Accuracy : 98.30
# time per epoch : 1.05 sec
#
#
# #####################################################
#
#
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 28, 28, 4)         104
#
#  max_pooling2d_36 (MaxPoolin  (None, 14, 14, 4)        0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 8)         808
#
#  max_pooling2d_37 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 7, 7, 16)          3216
#
#  max_pooling2d_38 (MaxPoolin  (None, 4, 4, 16)         0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 256)               0
#
#  dense_24 (Dense)            (None, 24)                6168
#
#  dense_25 (Dense)            (None, 10)                250
#
# =================================================================
# Total params: 10,546
# Trainable params: 10,546
# Non-trainable params: 0
# _________________________________________________________________
#
#
# [Grid search] case No.12
# Kernel size of each conv. layer :  (5, 5)
# Num of neurons in Dense_H layer : 24
# Learning rate : 0.0010
#
# ↓↓↓↓↓ Start CNN training ↓↓↓↓↓
#
# [0 Epochs] Accuracy : 41.60%
# [1 Epochs] Accuracy : 81.01%
# [2 Epochs] Accuracy : 92.67%
# [3 Epochs] Accuracy : 94.61%
# [4 Epochs] Accuracy : 95.54%
# [5 Epochs] Accuracy : 96.32%
# [6 Epochs] Accuracy : 96.72%
# [7 Epochs] Accuracy : 97.09%
# [8 Epochs] Accuracy : 97.29%
# [9 Epochs] Accuracy : 97.41%
# [10 Epochs] Accuracy : 97.82%
# [11 Epochs] Accuracy : 97.87%
# [12 Epochs] Accuracy : 97.97%
# [13 Epochs] Accuracy : 98.15%
# [14 Epochs] Accuracy : 98.27%
# [15 Epochs] Accuracy : 98.24%
# [16 Epochs] Accuracy : 98.33%
# [17 Epochs] Accuracy : 98.48%
# [18 Epochs] Accuracy : 98.70%
# [19 Epochs] Accuracy : 98.64%
# [20 Epochs] Accuracy : 98.76%
# [21 Epochs] Accuracy : 98.83%
# [22 Epochs] Accuracy : 98.94%
# [23 Epochs] Accuracy : 98.87%
# [24 Epochs] Accuracy : 99.04%
# [25 Epochs] Accuracy : 98.93%
# [26 Epochs] Accuracy : 99.10%
# [27 Epochs] Accuracy : 99.12%
# [28 Epochs] Accuracy : 99.17%
# [29 Epochs] Accuracy : 99.31%
# [30 Epochs] Accuracy : 99.28%
# [31 Epochs] Accuracy : 99.20%
# [32 Epochs] Accuracy : 99.32%
# [33 Epochs] Accuracy : 99.11%
# [34 Epochs] Accuracy : 99.34%
# [35 Epochs] Accuracy : 99.41%
# [36 Epochs] Accuracy : 99.31%
# [37 Epochs] Accuracy : 99.43%
# [38 Epochs] Accuracy : 99.50%
# [39 Epochs] Accuracy : 99.51%
# [40 Epochs] Accuracy : 99.43%
# [41 Epochs] Accuracy : 99.38%
# [42 Epochs] Accuracy : 99.54%
# [43 Epochs] Accuracy : 99.55%
# [44 Epochs] Accuracy : 99.48%
# [45 Epochs] Accuracy : 99.48%
# [46 Epochs] Accuracy : 99.49%
# [47 Epochs] Accuracy : 99.57%
# [48 Epochs] Accuracy : 99.56%
# [49 Epochs] Accuracy : 99.58%
# [50 Epochs] Accuracy : 99.40%
# [51 Epochs] Accuracy : 99.48%
# [52 Epochs] Accuracy : 99.68%
# [53 Epochs] Accuracy : 99.70%
# [54 Epochs] Accuracy : 99.66%
# [55 Epochs] Accuracy : 99.48%
# [56 Epochs] Accuracy : 99.54%
# [57 Epochs] Accuracy : 99.69%
# [58 Epochs] Accuracy : 99.73%
# [59 Epochs] Accuracy : 99.63%
# [60 Epochs] Accuracy : 99.55%
# [61 Epochs] Accuracy : 99.54%
# [62 Epochs] Accuracy : 99.67%
# [63 Epochs] Accuracy : 99.65%
#
# [Final Epochs] Accuracy : 98.52
# time per epoch : 1.98 sec
#
#
# #####################################################

# %%
Tr_result_temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37a5015509ef> in <module>()
# ----> 1 Tr_result_temp
#
# NameError: name 'Tr_result_temp' is not defined

# %%
Tr_result_temp_pd.to_csv("./[CNN_models]/Training_result.csv", index=None)

# %%
Tr_result_temp_pd.sort_values('Accuracy',ascending= False)
# Out:
#     Case  Kernel_S  Dense_N  Learn_R  Accuracy
# 6    6.0       4.0     21.0    0.001    0.9849
# 8    8.0       5.0     12.0    0.001    0.9843
# 10  10.0       5.0     21.0    0.001    0.9828
# 1    1.0       3.0     18.0    0.001    0.9822
# 2    2.0       3.0     21.0    0.001    0.9814
# 5    5.0       4.0     18.0    0.001    0.9813
# 11  11.0       5.0     24.0    0.001    0.9813
# 3    3.0       3.0     24.0    0.001    0.9811
# 4    4.0       4.0     12.0    0.001    0.9801
# 0    0.0       3.0     12.0    0.001    0.9799
# 7    7.0       4.0     24.0    0.001    0.9798
# 9    9.0       5.0     18.0    0.001    0.9766

# %%
Epoch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8ab6e1bd795e> in <module>()
# ----> 1 Epoch
#
# NameError: name 'Epoch' is not defined

# %%
Tr_result_temp_pd
# Out:
#     Case  Kernel_S  Dense_N  Learn_R  Accuracy
# 0    0.0       3.0     12.0    0.001    0.9462
# 1    1.0       3.0     18.0    0.001    0.9581
# 2    2.0       3.0     21.0    0.001    0.9697
# 3    3.0       3.0     24.0    0.001    0.9729
# 4    4.0       4.0     12.0    0.001    0.9611
# 5    5.0       4.0     18.0    0.001    0.9762
# 6    6.0       4.0     21.0    0.001    0.9763
# 7    7.0       4.0     24.0    0.001    0.9746
# 8    8.0       5.0     12.0    0.001    0.9661
# 9    9.0       5.0     18.0    0.001    0.9767
# 10  10.0       5.0     21.0    0.001    0.9698
# 11  11.0       5.0     24.0    0.001    0.9795

# %%
Tr_result_temp_pd.sort_values('Accuracy',ascending = False)
# Out:
#     Case  Kernel_S  Dense_N  Learn_R  Accuracy
# 11  11.0       5.0     24.0    0.001    0.9795
# 9    9.0       5.0     18.0    0.001    0.9767
# 6    6.0       4.0     21.0    0.001    0.9763
# 5    5.0       4.0     18.0    0.001    0.9762
# 7    7.0       4.0     24.0    0.001    0.9746
# 3    3.0       3.0     24.0    0.001    0.9729
# 10  10.0       5.0     21.0    0.001    0.9698
# 2    2.0       3.0     21.0    0.001    0.9697
# 8    8.0       5.0     12.0    0.001    0.9661
# 4    4.0       4.0     12.0    0.001    0.9611
# 1    1.0       3.0     18.0    0.001    0.9581
# 0    0.0       3.0     12.0    0.001    0.9462

# %%
Tr_result_temp_pd.to_csv('Tr_result.csv')

# %%
a = pd.DataFrame(model.predict(TestData))

# %%
np.where(a != 1.0)
# Out:
# (array([   0,    0,    0, ..., 9999, 9999, 9999]),
#  array([0, 1, 2, ..., 7, 8, 9]))
